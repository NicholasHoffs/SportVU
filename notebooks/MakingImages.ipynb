# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/merged_csv/0021500001.csv')

# %%
df
# Out:
#          EVENT       TEAM_ID  PLAYER_ID     LOC_X     LOC_Y    LOC_Z  \
# 0          1.0 -1.000000e+00       -1.0  47.25031  26.14806  6.76567
# 1          1.0  1.610613e+09     2594.0  45.70423  15.57870  0.00000
# 2          1.0  1.610613e+09   200794.0  56.87016  22.95879  0.00000
# 3          1.0  1.610613e+09   201143.0  47.26914  24.47616  0.00000
# 4          1.0  1.610613e+09   201952.0  28.26728  23.73400  0.00000
# ...        ...           ...        ...       ...       ...      ...
# 1906141  472.0  1.610613e+09   101141.0  19.34044  13.18479  0.00000
# 1906142  472.0  1.610613e+09   202704.0  12.30729  21.98252  0.00000
# 1906143  472.0  1.610613e+09   202694.0   9.22396   4.06039  0.00000
# 1906144  472.0  1.610613e+09   203484.0   7.16108  15.60356  0.00000
# 1906145  472.0  1.610613e+09   203083.0  14.81918  19.75303  0.00000
#
#          GAME_CLOCK  SHOT_CLOCK  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PLAYER1_ID  \
# ...

# %%
df = df[df['PLAYER1_ID']==df['PLAYER_ID']]

# %%
df = df[df['EVENTMSGTYPE']==2]

# %%
df[df['EVENT']==2]
# Out:
#       EVENT       TEAM_ID  PLAYER_ID     LOC_X     LOC_Y  LOC_Z  GAME_CLOCK  \
# 1660    2.0  1.610613e+09   203083.0  33.69503  25.29581    0.0      717.41
# 1671    2.0  1.610613e+09   203083.0  33.50527  25.43572    0.0      717.37
# 1682    2.0  1.610613e+09   203083.0  33.33357  25.51744    0.0      717.33
# 1693    2.0  1.610613e+09   203083.0  33.19776  25.60114    0.0      717.29
# 1704    2.0  1.610613e+09   203083.0  33.05826  25.66761    0.0      717.25
# ...     ...           ...        ...       ...       ...    ...         ...
# 7138    2.0  1.610613e+09   203083.0  83.22478  21.10100    0.0      697.10
# 7149    2.0  1.610613e+09   203083.0  83.47665  21.06905    0.0      697.06
# 7160    2.0  1.610613e+09   203083.0  83.70311  21.02741    0.0      697.02
# 7171    2.0  1.610613e+09   203083.0  83.87516  21.04674    0.0      696.98
# 7182    2.0  1.610613e+09   203083.0  84.03633  21.00720    0.0      696.94
#
# ...

# %%
plt.plot(my_data['LOC_X'],my_data['LOC_Y'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Programming\Projects\SportsAnalytics\SportVU\notebooks\MakingImages.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Programming/Projects/SportsAnalytics/SportVU/notebooks/MakingImages.ipynb#ch0000006?line=0'>1</a> plt.plot(my_data['LOC_X'],my_data['LOC_Y'])
#
# NameError: name 'my_data' is not defined

# %%
my_data=df[df['EVENT']==2][['LOC_X','LOC_Y']]

# %%
import matplotlib.pyplot as plt
import numpy as np

def make_image(data, outputname, size=(1, 1), dpi=80):
    print('BRUH')
    ax = plt.subplot()
    ax.plot(data)
    plt.axis('off')
    plt.savefig("test.png", bbox_inches='tight')

# %%
ax = plt.subplot()
ax.plot(my_data['LOC_X'], my_data['LOC_Y'])
plt.axis('off')
plt.savefig("test.png", bbox_inches='tight')

# %%
df.groupby('EVENT').apply(lambda x: make_image(x[['LOC_X','LOC_Y']],'{x}'))
# Out:
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# BRUH
# Empty DataFrame
# Columns: []
# Index: []
