# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/merged_csv/0021500001.csv')
df = df[df['EVENT']==17]
df = df[df['PLAYER_ID']==-1]

# %%
LOC = df[['LOC_X','LOC_Y']]

# %%
LOC
# Out:
#          LOC_X     LOC_Y
# 58564  44.2877    7.3721
# 58575  46.7594    7.2423
# 58586  49.2305    7.1113
# 58597  51.9253    6.9760
# 58608  55.2345    6.8579
# ...        ...       ...
# 63459 -19.5587  250.0380
# 63470 -19.1392  250.2868
# 63481 -23.7645  245.3447
# 63492 -29.7373  239.6607
# 63503 -31.6720  238.7196
#
# [450 rows x 2 columns]

# %%
LOC.shape
# Out:
# (450, 2)

# %%
diffx = np.diff(LOC['LOC_X'])
diffy = np.diff(LOC['LOC_Y'])

diffx2 = np.square(diffx)
diffy2 = np.square(diffy)

dist = np.sqrt(diffx2+diffy2)

vel = np.array(dist/.04)

# %%
def moving_average(a, n=3) :
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    return np.array(ret[n - 1:] / n)

# %%
moving_average(vel).shape
# Out:
# (447,)

# %%
import plotly.express as px

# %%
diffx = np.diff(LOC['LOC_X'])
diffy = np.diff(LOC['LOC_Y'])

diffx2 = np.square(diffx)
diffy2 = np.square(diffy)

dist = np.sqrt(diffx2+diffy2)

vel = np.array(dist/.04)
vel_smooth = moving_average(vel,5)
acc = np.array(vel/.04)
acc_smooth = moving_average(acc,5)

# %%
px.line(vel_smooth)

# %%
px.line(acc_smooth)

# %%
df = pd.read_csv('../data/merged_csv/0021500001.csv')

# %%
sum(df['EVENT']==14)
# Out:
# 0
