# %%
import pandas as pd

# %%
import sys
sys.path.append('../py/')

from animate import animate_play

# %%
df=pd.read_csv('../data/merged_csv/0021500001.csv')
df[df['EVENT']==2]
# Out:
#       EVENT       TEAM_ID  PLAYER_ID     LOC_X     LOC_Y    LOC_Z  GAME_CLOCK  \
# 1650    2.0 -1.000000e+00       -1.0  -46.2727  230.5912  1.94592      717.41
# 1651    2.0  1.610613e+09     2594.0   33.5688  238.3620  0.00000      717.41
# 1652    2.0  1.610613e+09   200794.0   -9.6555  418.7784  0.00000      717.41
# 1653    2.0  1.610613e+09   201143.0    6.1169  201.2104  0.00000      717.41
# 1654    2.0  1.610613e+09   201952.0   -1.5548  287.0193  0.00000      717.41
# ...     ...           ...        ...       ...       ...      ...         ...
# 7178    2.0  1.610613e+09   101141.0  -23.9324    3.5929  0.00000      696.94
# 7179    2.0  1.610613e+09   202704.0  -29.8330  180.3862  0.00000      696.94
# 7180    2.0  1.610613e+09   202694.0   95.8023  130.1096  0.00000      696.94
# 7181    2.0  1.610613e+09   203484.0 -145.9765   96.5572  0.00000      696.94
# 7182    2.0  1.610613e+09   203083.0  -39.9280   52.1367  0.00000      696.94
#
# ...

# %%
df
# Out:
#          EVENT       TEAM_ID  PLAYER_ID     LOC_X     LOC_Y    LOC_Z  \
# 0          1.0 -1.000000e+00       -1.0   11.4806  419.9969  6.76567
# 1          1.0  1.610613e+09     2594.0   94.2130  409.5423  0.00000
# 2          1.0  1.610613e+09   200794.0  -20.4121  323.7984  0.00000
# 3          1.0  1.610613e+09   201143.0   -5.2384  419.8086  0.00000
# 4          1.0  1.610613e+09   201952.0   12.6600  235.1728  0.00000
# ...        ...           ...        ...       ...       ...      ...
# 1906141  472.0  1.610613e+09   101141.0  118.1521  145.9044  0.00000
# 1906142  472.0  1.610613e+09   202704.0   30.1748   75.5729  0.00000
# 1906143  472.0  1.610613e+09   202694.0  209.3961   44.7396  0.00000
# 1906144  472.0  1.610613e+09   203484.0   93.9644   24.1108  0.00000
# 1906145  472.0  1.610613e+09   203083.0   52.4697  100.6918  0.00000
#
#          GAME_CLOCK  SHOT_CLOCK  LOC_X_original  LOC_Y_original  EVENTMSGTYPE  \
# ...

# %%
animate_play(df, 2, 'first_figure')
# Out:
# e:\Programming\Projects\SportsAnalytics\SportVU\notebooks\../py\animate.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'MOMENT_NUM'] = np.divmod(np.arange(length),11)[0]+1
# e:\Programming\Projects\SportsAnalytics\SportVU\notebooks\../py\animate.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:,'LOC_Z'] = df['LOC_Z']+1
